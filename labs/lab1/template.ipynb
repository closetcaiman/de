# %% [markdown]
# # PCA — dimensionality reduction

# %% [markdown]
# ## New York Times data analysis

# %% [markdown]
# ### Task 1.
#
# Load the NYT dataset as a `DataFrame` (pandas). Extract the feature matrix by dropping the first 9 metadata columns; store the column names as the vocabulary header.

# %% [markdown]
# ### Task 2.
#
# Display 20 randomly chosen words from the vocabulary header.

# %% [markdown]
# ### Task 3.
#
# Fit PCA on the feature matrix (metadata columns excluded) and transform the data.

# %% [markdown]
# ### Task 4.
#
# For the **first principal component**, display the 15 words with the highest loadings (together with the column names). What semantic concept do they correspond to?

# %% [markdown]
# ### Task 5.
#
# For the **first principal component**, display the 15 words with the lowest loadings. What semantic concept do they correspond to?

# %% [markdown]
# ### Task 6.
#
# Repeat tasks 4 and 5 for the **second principal component**. Comment on the results.

# %% [markdown]
# ### Task 7.
#
# Visualize the data projected onto the first 2 principal components. Color points by class label (art / music).

# %% [markdown]
# ### Task 8.
#
# Plot the explained variance ratio as a function of PC index (scree plot). What fraction of variance is retained in the first 10 components?

# %% [markdown]
# ### Task 9.
#
# Comment on how non-default values of the `sklearn.decomposition.PCA` constructor arguments could be useful in this exercise:
#
# - `n_components`: `None`, `int`, `float`, `'mle'`
# - `copy`
# - `whiten`
# - `svd_solver`: `'auto'`, `'full'`, `'arpack'`, `'randomized'`

# %% [markdown]
# ### Task 10. _(optional)_
#
# Compare t-SNE and UMAP with PCA for a 2D visualization of the NYT data. Do the non-linear methods better separate the art and music classes?

# %% [markdown]
# ## 04Cars data analysis

# %% [markdown]
# ### Task 1.
#
# Load the 04Cars dataset as a `DataFrame`. Select the last 11 columns — these numerical features will serve as PCA input.

# %% [markdown]
# ### Task 2.
#
# Normalize the data so that each feature has mean 0 and variance 1 (`sklearn.preprocessing.scale`).

# %% [markdown]
# ### Task 3.
#
# Fit PCA on the normalized data. Plot both the absolute and relative explained variance as a function of PC index. What fraction of variance is retained when reducing to 2 and 3 dimensions?

# %% [markdown]
# ### Task 4.
#
# Display the PC1 and PC2 loadings alongside feature names in a table. What do values close to zero indicate? Identify the car properties associated with:
#
# - Largest PC1 loadings
# - Smallest PC1 loadings
# - Largest PC2 loadings
# - Smallest PC2 loadings

# %% [markdown]
# ### Task 5.
#
# Visualize the data projected onto the first 2 PCs. Label each point with the car model name. What types of cars appear in different regions of the plot?

# %% [markdown]
# ### Task 6.
#
# On the same 2D scatter plot, overlay the projected feature vectors (_biplot_). What does this type of visualization convey?

# %% [markdown]
# ## LFW — Labeled Faces in the Wild

# %% [markdown]
# ### Task 1.
#
# Load the LFW dataset using `fetch_lfw_people(min_faces_per_person=50, resize=0.4)`. Split into train and test sets.

# %% [markdown]
# ### Task 2.
#
# Fit PCA with 100 components (`whiten=True`, `svd_solver='randomized'`) on the training set. Transform both the training and test sets.

# %% [markdown]
# ### Task 3.
#
# Train an SVM classifier (`kernel='rbf'`) and an MLP on the PCA-reduced features. Evaluate both with `classification_report`.

# %% [markdown]
# ### Task 4.
#
# Repeat with 50 PCA components. Compare the classification results between 100 and 50 components.

# %% [markdown]
# ### Task 5.
#
# Visualize the first 20 eigenfaces as a 4×5 image grid.

# %% [markdown]
# ## Incremental PCA

# %% [markdown]
# ### Task 1.
#
# Generate a large synthetic dataset with `make_blobs` (100,000 samples, 100 features, 5 cluster centers, `random_state=42`). Normalize and split into train/test sets.

# %% [markdown]
# ### Task 2.
#
# Fit standard `PCA` and `IncrementalPCA` (batch_size=1000), both with 10 components. Measure and compare execution time and peak memory usage for each.

# %% [markdown]
# ### Task 3.
#
# Plot the explained variance ratio for both PCA and IPCA on the same chart. Are the results similar?

# %% [markdown]
# ### Task 4.
#
# Visualize the 2D projection (first 2 PCs) side by side for PCA and IPCA.

# %% [markdown]
# ### Task 5. _(optional)_
#
# Test scalability: measure fit time for PCA and IPCA at dataset sizes of 10k, 50k, and 100k samples. Plot the results.
